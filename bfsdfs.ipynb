# %%
graph = {
    'A' : ['B','C'],
    'B' : ['D','A','C'],
    'C' : ['D','B'],
    'D' : ['A']
}
for node in graph:
    print(node,"->",graph[node])
    
def dfs(graph, node, visited = None):
    if visited is None :
        visited = set()
    visited.add(node)
    print(node , end =" ")
    
    for neighbour in graph[node]:
        if neighbour not in visited:
            dfs(graph , neighbour , visited)
    return visited
print("\n\nDFS traversal from node 'A' is:")
print(node , 'A')


from collections import deque

def bfs(graph,start_node):

  visited = set()
  queue = deque()

  visited.add(start_node)
  queue.append(start_node)

  while queue:
    node = queue.popleft()
    print(node, end=" ")
    
    for neighbour in graph[node]:
        if neighbour not in visited:
            visited.add(neighbour)
            queue.append(neighbour)

  return visited 

print("bfs traversal of A is:")
print(node,'A')
# Out:
# A -> ['B', 'C']
# B -> ['D', 'A', 'C']
# C -> ['D', 'B']
# D -> ['A']
#
#
# DFS traversal from node 'A' is:
# D A
# bfs traversal of A is:
# D A
